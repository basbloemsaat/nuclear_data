# %%
import pandas as pd
import numpy as np
from dataclasses import dataclass, field
import re

# %%
with open("../data/nubase_4.mas20.txt", "r") as f:
    lines = f.readlines()


half_life_units_factors: dict[str, float] = {
    "ys": 1e-24,
    "zs": 1e-21,
    "as": 1e-18,
    "fs": 1e-15,
    "ps": 1e-12,
    "ns": 1e-9,
    "us": 1e-6,
    "ms": 1e-3,
    "s": 1,
    "m": 60,
    "h": 60 * 60,
    "d": 24 * 60 * 60,
    "y": 31557600,
    "ky": 31557600 * 1e3,
    "My": 31557600 * 1e6,
    "Gy": 31557600 * 1e9,
    "Ty": 31557600 * 1e12,
    "Py": 31557600 * 1e15,
    "Ey": 31557600 * 1e18,
    "Yy": 31557600 * 1e21,
    "Zy": 31557600 * 1e24,
}


def convert_half_life_to_s(half_life: float, unit: str) -> float:
    if unit not in half_life_units_factors:
        raise ValueError(f"Unit {unit} not found in half_life_units_factors")
    return half_life * half_life_units_factors[unit]

# %%
@dataclass
class Isotope:
    mass_number_AAA: int
    atomic_number_ZZZ: int
    atomic_number_i: int
    nucleide: str
    element: str
    s: str
    mass_excess: float | None  # Mass Excess in keV
    mass_excess_systematics: bool
    mass_excess_uncertainty: float | None  # Mass Excess uncertainty in keV
    mass_excess_uncertainty_systematics: bool
    # isomer_excitation_energy: float | None = None  # Isomer excitation energy in keV
    # isomer_excitation_energy_systematics: bool
    # isomer_excitation_energy_uncertainty: float | None = (
    #     None  # Isomer excitation energy uncertainty in keV
    # )
    # isomer_excitation_energy_uncertainty_systematics: bool
    # origin_of_excitation_energy: str = ""

    stable: bool
    p_unstable: bool
    half_life: float | None  # Half-life in s
    # half_life_systematics: bool
    # half_life_uncertainty: float | None  # Half-life uncertainty in s
    half_life_str: str

    nubase2020_line: str = ""

    isomers: list["Isotope"] = field(default_factory=list)
    isobaric_analog_states: list["Isotope"] = field(default_factory=list)

    def for_json(self):
        return {
            "mass_number_AAA": self.mass_number_AAA,
            "atomic_number_ZZZ": self.atomic_number_ZZZ,
            "atomic_number_i": self.atomic_number_i,
            "nucleide": self.nucleide,
            "element": self.element,
            "s": self.s,
            "mass_excess": self.mass_excess,
            "mass_excess_systematics": self.mass_excess_systematics,
            "mass_excess_uncertainty": self.mass_excess_uncertainty,
            "mass_excess_uncertainty_systematics": self.mass_excess_uncertainty_systematics,
            "stable": self.stable,
            "p_unstable": self.p_unstable,
            "half_life": self.half_life,
            "half_life_str": self.half_life_str,
            "nubase2020_line": self.nubase2020_line,
            "isomers": [i.for_json() for i in self.isomers],
            "isobaric_analog_states": [i.for_json() for i in self.isobaric_analog_states],
        }


def isotope_from_line(line):
    mass_number_AAA = int(line[0:3])
    atomic_number_ZZZ = int(line[4:7])
    atomic_number_i = int(line[7:8])
    element_A = line[11:16].strip()
    s = line[16:17].strip()

    mass_excess = line[18:31].strip()
    mass_excess_r = mass_excess.replace("#", "")
    mass_excess_systematics = mass_excess != mass_excess_r
    if not mass_excess_r == "":
        mass_excess = float(mass_excess_r)

    mass_excess_uncertainty = line[31:42].strip()
    mass_excess_uncertainty_r = mass_excess_uncertainty.replace("#", "")
    mass_excess_uncertainty_systematics = (
        mass_excess_uncertainty == mass_excess_uncertainty_r
    )
    if not mass_excess_uncertainty_r == "":
        mass_excess_uncertainty = float(mass_excess_uncertainty_r)

    half_life_raw = line[69:78].strip()
    half_life_unit = line[78:80].strip()

    stable = False
    p_unstable = False

    if half_life_raw == "stbl":
        half_life = None
        stable = True
    elif half_life_raw == "p-unst":
        half_life = None
        p_unstable = True
    elif half_life_raw == "":
        half_life = None
    else:
        hlnstr = re.sub(r"[^0-9.]", "", half_life_raw)
        half_life = convert_half_life_to_s(float(hlnstr), half_life_unit)

    i = Isotope(
        nubase2020_line=line,
        mass_number_AAA=mass_number_AAA,
        atomic_number_ZZZ=atomic_number_ZZZ,
        atomic_number_i=atomic_number_i,
        nucleide=element_A,
        element=re.sub(r"[0-9]", "", element_A),
        s=s,
        mass_excess=mass_excess,
        mass_excess_systematics=mass_excess_systematics,
        mass_excess_uncertainty=mass_excess_uncertainty,
        mass_excess_uncertainty_systematics=mass_excess_uncertainty_systematics,
        half_life_str=f"{half_life_raw} {half_life_unit}".strip(),
        half_life=half_life,
        stable=stable,
        p_unstable=p_unstable,
    )
    return i


isotopes: list[Isotope] = []
isotope_lookup: dict[str, Isotope] = {}

for line in lines:
    if line[0] == "#":
        continue
    i = isotope_from_line(line)

    if i.s in ["i", "j"]:
        isotope_lookup[i.nucleide].isobaric_analog_states.append(i)
    elif i.s in ["m", "n"]:
        isotope_lookup[i.nucleide].isomers.append(i)
    else:
        isotopes.append(i)
        isotope_lookup[i.nucleide] = i

# isotopes

# convert isotopes to json
import json

isotopes_json = [i.for_json() for i in isotopes]
with open("../docs/data/nubase_4.mas20.json", "w") as f:
    json.dump(isotopes_json, f, indent=2)


isotope_lookup
# Out:
# {'1n': Isotope(mass_number_AAA=1, atomic_number_ZZZ=0, atomic_number_i=0, nucleide='1n', element='n', s='', mass_excess=8071.3181, mass_excess_systematics=False, mass_excess_uncertainty=0.0004, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=609.8, half_life_str='609.8 s', nubase2020_line='001 0000   1n       8071.3181     0.0004                              609.8    s 0.6    1/2+*         06          1932 B-=100\n', isomers=[], isobaric_analog_states=[]),
#  '1H': Isotope(mass_number_AAA=1, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='1H', element='H', s='', mass_excess=7288.971064, mass_excess_systematics=False, mass_excess_uncertainty=1.3e-05, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='001 0010   1H       7288.971064   0.000013                            stbl              1/2+*         06          1920 IS=99.9855 78\n', isomers=[], isobaric_analog_states=[]),
#  '2H': Isotope(mass_number_AAA=2, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='2H', element='H', s='', mass_excess=13135.722895, mass_excess_systematics=False, mass_excess_uncertainty=1.5e-05, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='002 0010   2H      13135.722895   0.000015                            stbl              1+*           03          1932 IS=0.0145 78\n', isomers=[], isobaric_analog_states=[]),
#  '3H': Isotope(mass_number_AAA=3, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='3H', element='H', s='', mass_excess=14949.8109, mass_excess_systematics=False, mass_excess_uncertainty=8e-05, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=388789632.0, half_life_str='12.32 y', nubase2020_line='003 0010   3H      14949.81090    0.00008                              12.32   y 0.02   1/2+*         00          1934 B-=100\n', isomers=[], isobaric_analog_states=[]),
#  '3He': Isotope(mass_number_AAA=3, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='3He', element='He', s='', mass_excess=14931.21888, mass_excess_systematics=False, mass_excess_uncertainty=6e-05, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='003 0020   3He     14931.21888    0.00006                             stbl              1/2+*         98          1934 IS=0.0002 2\n', isomers=[], isobaric_analog_states=[]),
#  '3Li': Isotope(mass_number_AAA=3, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='3Li', element='Li', s='', mass_excess=28670.0, mass_excess_systematics=True, mass_excess_uncertainty=2000.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=True, half_life=None, half_life_str='p-unst', nubase2020_line='003 0030   3Li     28670#      2000#                                  p-unst            3/2-#         98               p ?\n', isomers=[], isobaric_analog_states=[]),
#  '4H': Isotope(mass_number_AAA=4, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='4H', element='H', s='', mass_excess=24620.0, mass_excess_systematics=False, mass_excess_uncertainty=100.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.3899999999999998e-22, half_life_str='139 ys', nubase2020_line='004 0010   4H      24620        100                                   139     ys 10     2-            98          1981 n=100\n', isomers=[], isobaric_analog_states=[]),
#  '4He': Isotope(mass_number_AAA=4, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='4He', element='He', s='', mass_excess=2424.91587, mass_excess_systematics=False, mass_excess_uncertainty=0.00015, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='004 0020   4He      2424.91587    0.00015                             stbl              0+            98          1908 IS=99.9998 2\n', isomers=[], isobaric_analog_states=[]),
#  '4Li': Isotope(mass_number_AAA=4, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='4Li', element='Li', s='', mass_excess=25320.0, mass_excess_systematics=False, mass_excess_uncertainty=210.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=9.099999999999999e-23, half_life_str='91 ys', nubase2020_line='004 0030   4Li     25320        210                                    91     ys 9      2-            98          1965 p=100\n', isomers=[], isobaric_analog_states=[]),
#  '5H': Isotope(mass_number_AAA=5, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='5H', element='H', s='', mass_excess=32890.0, mass_excess_systematics=False, mass_excess_uncertainty=90.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=8.599999999999999e-23, half_life_str='86 ys', nubase2020_line='005 0010   5H      32890         90                                    86     ys 6      (1/2+)        19          1987 2n=100\n', isomers=[], isobaric_analog_states=[]),
#  '5He': Isotope(mass_number_AAA=5, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='5He', element='He', s='', mass_excess=11231.0, mass_excess_systematics=False, mass_excess_uncertainty=20.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=6.019999999999999e-22, half_life_str='602 ys', nubase2020_line='005 0020   5He     11231         20                                   602     ys 22     3/2-          02          1937 n=100\n', isomers=[], isobaric_analog_states=[]),
#  '5Li': Isotope(mass_number_AAA=5, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='5Li', element='Li', s='', mass_excess=11680.0, mass_excess_systematics=False, mass_excess_uncertainty=50.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=3.6999999999999995e-22, half_life_str='370 ys', nubase2020_line='005 0030   5Li     11680         50                                   370     ys 30     3/2-          02          1941 p=100\n', isomers=[], isobaric_analog_states=[]),
#  '5Be': Isotope(mass_number_AAA=5, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='5Be', element='Be', s='', mass_excess=37140.0, mass_excess_systematics=True, mass_excess_uncertainty=2000.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=True, half_life=None, half_life_str='p-unst', nubase2020_line='005 0040   5Be     37140#      2000#                                  p-unst            1/2+#         18               p ?\n', isomers=[], isobaric_analog_states=[]),
#  '6H': Isotope(mass_number_AAA=6, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='6H', element='H', s='', mass_excess=41880.0, mass_excess_systematics=False, mass_excess_uncertainty=250.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2.94e-22, half_life_str='294 ys', nubase2020_line='006 0010   6H      41880        250                                   294     ys 67     2-#           19          1984 n ?;3n ?\n', isomers=[], isobaric_analog_states=[]),
#  '6He': Isotope(mass_number_AAA=6, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='6He', element='He', s='', mass_excess=17592.1, mass_excess_systematics=False, mass_excess_uncertainty=0.05, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.80692, half_life_str='806.92 ms', nubase2020_line='006 0020   6He     17592.10       0.05                                806.92  ms 0.24   0+            02          1936 B-=100;B-d=0.000278 18\n', isomers=[], isobaric_analog_states=[]),
#  '6Li': Isotope(mass_number_AAA=6, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='6Li', element='Li', s='', mass_excess=14086.8804, mass_excess_systematics=False, mass_excess_uncertainty=0.0014, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='006 0030   6Li     14086.8804     0.0014                              stbl              1+*           02          1921 IS=4.85 171\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=6, atomic_number_ZZZ=3, atomic_number_i=8, nucleide='6Li', element='Li', s='i', mass_excess=17649.76, mass_excess_systematics=False, mass_excess_uncertainty=0.1, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5.6e-17, half_life_str='56 as', nubase2020_line='006 0038   6Li  i  17649.76       0.10     3562.88       0.10          56     as 14     0+      T=1   02          1981 IT=100\n', isomers=[], isobaric_analog_states=[])]),
#  '6Be': Isotope(mass_number_AAA=6, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='6Be', element='Be', s='', mass_excess=18375.0, mass_excess_systematics=False, mass_excess_uncertainty=5.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5e-21, half_life_str='5.0 zs', nubase2020_line='006 0040   6Be     18375          5                                     5.0   zs 0.3    0+            02          1958 2p=100\n', isomers=[], isobaric_analog_states=[]),
#  '6B': Isotope(mass_number_AAA=6, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='6B', element='B', s='', mass_excess=47320.0, mass_excess_systematics=True, mass_excess_uncertainty=2000.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=True, half_life=None, half_life_str='p-unst', nubase2020_line='006 0050   6B      47320#      2000#                                  p-unst            2-#                            2p ?\n', isomers=[], isobaric_analog_states=[]),
#  '7H': Isotope(mass_number_AAA=7, atomic_number_ZZZ=1, atomic_number_i=0, nucleide='7H', element='H', s='', mass_excess=49140.0, mass_excess_systematics=True, mass_excess_uncertainty=1000.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=False, half_life=6.52e-22, half_life_str='652 ys', nubase2020_line='007 0010   7H      49140#      1000#                                  652     ys 558    1/2+#         17          2003 2n ?\n', isomers=[], isobaric_analog_states=[]),
#  '7He': Isotope(mass_number_AAA=7, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='7He', element='He', s='', mass_excess=26073.0, mass_excess_systematics=False, mass_excess_uncertainty=8.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2.5099999999999994e-21, half_life_str='2.51 zs', nubase2020_line='007 0020   7He     26073          8                                     2.51  zs 0.07   (3/2)-        03          1967 n=100\n', isomers=[], isobaric_analog_states=[]),
#  '7Li': Isotope(mass_number_AAA=7, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='7Li', element='Li', s='', mass_excess=14907.105, mass_excess_systematics=False, mass_excess_uncertainty=0.004, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='007 0030   7Li     14907.105      0.004                               stbl              3/2-*         03          1921 IS=95.15 171\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=7, atomic_number_ZZZ=3, atomic_number_i=8, nucleide='7Li', element='Li', s='i', mass_excess=26150.0, mass_excess_systematics=False, mass_excess_uncertainty=30.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='007 0038   7Li  i  26150         30       11250         30       RQ                     3/2-    T=3/2 03               \n', isomers=[], isobaric_analog_states=[])]),
#  '7Be': Isotope(mass_number_AAA=7, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='7Be', element='Be', s='', mass_excess=15769.0, mass_excess_systematics=False, mass_excess_uncertainty=0.07, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=4598208.0, half_life_str='53.22 d', nubase2020_line='007 0040   7Be     15769.00       0.07                                 53.22   d 0.06   3/2-          03          1938 EC=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=7, atomic_number_ZZZ=4, atomic_number_i=8, nucleide='7Be', element='Be', s='i', mass_excess=26750.0, mass_excess_systematics=False, mass_excess_uncertainty=30.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='007 0048   7Be  i  26750         30       10980         30       RQ                     3/2-    T=3/2 03               p ?;3He ?;A ?\n', isomers=[], isobaric_analog_states=[])]),
#  '7B': Isotope(mass_number_AAA=7, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='7B', element='B', s='', mass_excess=27677.0, mass_excess_systematics=False, mass_excess_uncertainty=25.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5.7e-22, half_life_str='570 ys', nubase2020_line='007 0050   7B      27677         25                                   570     ys 14     (3/2-)        14          1967 p=100\n', isomers=[], isobaric_analog_states=[]),
#  '8He': Isotope(mass_number_AAA=8, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='8He', element='He', s='', mass_excess=31609.68, mass_excess_systematics=False, mass_excess_uncertainty=0.09, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.11950000000000001, half_life_str='119.5 ms', nubase2020_line='008 0020   8He     31609.68       0.09                                119.5   ms 1.5    0+            05          1965 B-=100;B-n=16 1;B-t=0.9 1\n', isomers=[], isobaric_analog_states=[]),
#  '8Li': Isotope(mass_number_AAA=8, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='8Li', element='Li', s='', mass_excess=20945.8, mass_excess_systematics=False, mass_excess_uncertainty=0.05, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.8387000000000001, half_life_str='838.7 ms', nubase2020_line='008 0030   8Li     20945.80       0.05                                838.7   ms 0.3    2+            05          1935 B-=100;B-A=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=8, atomic_number_ZZZ=3, atomic_number_i=8, nucleide='8Li', element='Li', s='i', mass_excess=31768.0, mass_excess_systematics=False, mass_excess_uncertainty=5.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='008 0038   8Li  i  31768          5       10822          5       RQ                     0+      T=2   05               \n', isomers=[], isobaric_analog_states=[])]),
#  '8Be': Isotope(mass_number_AAA=8, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='8Be', element='Be', s='', mass_excess=4941.67, mass_excess_systematics=False, mass_excess_uncertainty=0.04, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=8.190000000000001e-17, half_life_str='81.9 as', nubase2020_line='008 0040   8Be      4941.67       0.04                                 81.9   as 3.7    0+            05          1932 A=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=8, atomic_number_ZZZ=4, atomic_number_i=8, nucleide='8Be', element='Be', s='i', mass_excess=21568.0, mass_excess_systematics=False, mass_excess_uncertainty=3.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='008 0048   8Be  i  21568          3       16626          3                              2+  frg T=1               2004 A~100\n', isomers=[], isobaric_analog_states=[]), Isotope(mass_number_AAA=8, atomic_number_ZZZ=4, atomic_number_i=9, nucleide='8Be', element='Be', s='j', mass_excess=32436.0, mass_excess_systematics=False, mass_excess_uncertainty=2.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='008 0049   8Be  j  32436.0        2.0     27494.3        2.0     RQ                     0+      T=2   05               n=39.4;d=27.0;3H=11.7;A=7.9;p=6.9;3He=6.6;IT=0.60\n', isomers=[], isobaric_analog_states=[])]),
#  '8B': Isotope(mass_number_AAA=8, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='8B', element='B', s='', mass_excess=22921.6, mass_excess_systematics=False, mass_excess_uncertainty=1.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.7719, half_life_str='771.9 ms', nubase2020_line='008 0050   8B      22921.6        1.0                                 771.9   ms 0.9    2+            05          1950 B+=100;B+A=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=8, atomic_number_ZZZ=5, atomic_number_i=8, nucleide='8B', element='B', s='i', mass_excess=33546.0, mass_excess_systematics=False, mass_excess_uncertainty=8.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='008 0058   8B   i  33546          8       10624          8       RQ                     0+      T=2   05          1975 \n', isomers=[], isobaric_analog_states=[])]),
#  '8C': Isotope(mass_number_AAA=8, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='8C', element='C', s='', mass_excess=35064.0, mass_excess_systematics=False, mass_excess_uncertainty=18.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=3.4999999999999996e-21, half_life_str='3.5 zs', nubase2020_line='008 0060   8C      35064         18                                     3.5   zs 1.4    0+            18          1974 2p=100\n', isomers=[], isobaric_analog_states=[]),
#  '9He': Isotope(mass_number_AAA=9, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='9He', element='He', s='', mass_excess=40940.0, mass_excess_systematics=False, mass_excess_uncertainty=50.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2.5e-21, half_life_str='2.5 zs', nubase2020_line='009 0020   9He     40940         50                                     2.5   zs 2.3    1/2(+)        06          1987 n=100\n', isomers=[], isobaric_analog_states=[]),
#  '9Li': Isotope(mass_number_AAA=9, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='9Li', element='Li', s='', mass_excess=24954.91, mass_excess_systematics=False, mass_excess_uncertainty=0.19, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.1782, half_life_str='178.2 ms', nubase2020_line='009 0030   9Li     24954.91       0.19                                178.2   ms 0.4    3/2-          06          1951 B-=100;B-n=50.5 10\n', isomers=[], isobaric_analog_states=[]),
#  '9Be': Isotope(mass_number_AAA=9, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='9Be', element='Be', s='', mass_excess=11348.45, mass_excess_systematics=False, mass_excess_uncertainty=0.08, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='009 0040   9Be     11348.45       0.08                                stbl              3/2-*         06          1921 IS=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=9, atomic_number_ZZZ=4, atomic_number_i=8, nucleide='9Be', element='Be', s='i', mass_excess=25738.8, mass_excess_systematics=False, mass_excess_uncertainty=1.7, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.25e-18, half_life_str='1.25 as', nubase2020_line='009 0048   9Be  i  25738.8        1.7     14390.3        1.7     RQ     1.25  as 0.10   3/2-    T=3/2 06          1976 \n', isomers=[], isobaric_analog_states=[])]),
#  '9B': Isotope(mass_number_AAA=9, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='9B', element='B', s='', mass_excess=12416.5, mass_excess_systematics=False, mass_excess_uncertainty=0.9, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=7.999999999999999e-19, half_life_str='800 zs', nubase2020_line='009 0050   9B      12416.5        0.9                                 800     zs 300    3/2-          06          1940 p=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=9, atomic_number_ZZZ=5, atomic_number_i=8, nucleide='9B', element='B', s='i', mass_excess=27071.0, mass_excess_systematics=False, mass_excess_uncertainty=2.3, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='009 0058   9B   i  27071.0        2.3     14654.5        2.5     RQ                     3/2-    T=3/2 06               \n', isomers=[], isobaric_analog_states=[])]),
#  '9C': Isotope(mass_number_AAA=9, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='9C', element='C', s='', mass_excess=28911.0, mass_excess_systematics=False, mass_excess_uncertainty=2.1, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.1265, half_life_str='126.5 ms', nubase2020_line='009 0060   9C      28911.0        2.1                                 126.5   ms 0.9    3/2-          06          1964 B+=100;B+p=7.5 6;B+A=38.4 16\n', isomers=[], isobaric_analog_states=[]),
#  '10He': Isotope(mass_number_AAA=10, atomic_number_ZZZ=2, atomic_number_i=0, nucleide='10He', element='He', s='', mass_excess=49200.0, mass_excess_systematics=False, mass_excess_uncertainty=90.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2.6e-22, half_life_str='260 ys', nubase2020_line='010 0020   10He    49200         90                                   260     ys 40     0+            07          1994 2n=100\n', isomers=[], isobaric_analog_states=[]),
#  '10Li': Isotope(mass_number_AAA=10, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='10Li', element='Li', s='', mass_excess=33053.0, mass_excess_systematics=False, mass_excess_uncertainty=13.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2e-21, half_life_str='2.0 zs', nubase2020_line='010 0030   10Li    33053         13                                     2.0   zs 0.5    (1-,2-)       07          1975 n=100\n', isomers=[Isotope(mass_number_AAA=10, atomic_number_ZZZ=3, atomic_number_i=1, nucleide='10Li', element='Li', s='m', mass_excess=33250.0, mass_excess_systematics=False, mass_excess_uncertainty=40.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=3.7e-21, half_life_str='3.7 zs', nubase2020_line='010 0031   10Li m  33250         40         200         40       RQ     3.7   zs 1.5    1+            07          1994 IT=100\n', isomers=[], isobaric_analog_states=[]), Isotope(mass_number_AAA=10, atomic_number_ZZZ=3, atomic_number_i=2, nucleide='10Li', element='Li', s='n', mass_excess=33530.0, mass_excess_systematics=False, mass_excess_uncertainty=40.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.35e-21, half_life_str='1.35 zs', nubase2020_line='010 0032   10Li n  33530         40         480         40       RQ     1.35  zs 0.24   (2+)          07          1993 IT=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '10Be': Isotope(mass_number_AAA=10, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='10Be', element='Be', s='', mass_excess=12607.49, mass_excess_systematics=False, mass_excess_uncertainty=0.08, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=43770391200000.0, half_life_str='1.387 My', nubase2020_line='010 0040   10Be    12607.49       0.08                                  1.387 My 0.012  0+            07          1935 B-=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=10, atomic_number_ZZZ=4, atomic_number_i=8, nucleide='10Be', element='Be', s='i', mass_excess=33787.0, mass_excess_systematics=False, mass_excess_uncertainty=21.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='010 0048   10Be i  33787         21       21179         21       RQ                     (2-)    T=2   07               n ?;p ?;3H ?\n', isomers=[], isobaric_analog_states=[])]),
#  '10B': Isotope(mass_number_AAA=10, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='10B', element='B', s='', mass_excess=12050.611, mass_excess_systematics=False, mass_excess_uncertainty=0.015, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='010 0050   10B     12050.611      0.015                               stbl              3+*           07          1920 IS=19.65 44\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=10, atomic_number_ZZZ=5, atomic_number_i=8, nucleide='10B', element='B', s='i', mass_excess=13790.66, mass_excess_systematics=False, mass_excess_uncertainty=0.04, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='010 0058   10B  i  13790.66       0.04     1740.05       0.04                           0+      T=1   07               IT=100\n', isomers=[], isobaric_analog_states=[])]),
#  '10C': Isotope(mass_number_AAA=10, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='10C', element='C', s='', mass_excess=15698.67, mass_excess_systematics=False, mass_excess_uncertainty=0.07, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=19.3011, half_life_str='19.3011 s', nubase2020_line='010 0060   10C     15698.67       0.07                                 19.3011 s 0.0015 0+            07          1949 B+=100\n', isomers=[], isobaric_analog_states=[]),
#  '10N': Isotope(mass_number_AAA=10, atomic_number_ZZZ=7, atomic_number_i=0, nucleide='10N', element='N', s='', mass_excess=38800.0, mass_excess_systematics=False, mass_excess_uncertainty=400.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.43e-22, half_life_str='143 ys', nubase2020_line='010 0070   10N     38800        400                                   143     ys 36     1-,2-         17          2002 p ?\n', isomers=[], isobaric_analog_states=[]),
#  '11Li': Isotope(mass_number_AAA=11, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='11Li', element='Li', s='', mass_excess=40728.3, mass_excess_systematics=False, mass_excess_uncertainty=0.6, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.00875, half_life_str='8.75 ms', nubase2020_line='011 0030   11Li    40728.3        0.6                                   8.75  ms 0.06   3/2-*         12          1966 B-=100;B-n=86.3 9;B-2n=4.1 4;B-3n=1.9 2;B-A=1.7 3;B-d=0.0130 13;B-t=0.0093 8\n', isomers=[], isobaric_analog_states=[]),
#  '11Be': Isotope(mass_number_AAA=11, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='11Be', element='Be', s='', mass_excess=20177.17, mass_excess_systematics=False, mass_excess_uncertainty=0.24, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=13.76, half_life_str='13.76 s', nubase2020_line='011 0040   11Be    20177.17       0.24                                 13.76   s 0.07   1/2+*         12          1958 B-=100;B-A=3.3 1;B-p=0.0013 3;B-n ?\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=11, atomic_number_ZZZ=4, atomic_number_i=8, nucleide='11Be', element='Be', s='i', mass_excess=41336.0, mass_excess_systematics=False, mass_excess_uncertainty=20.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=9.3e-22, half_life_str='0.93 zs', nubase2020_line='011 0048   11Be i  41336         20       21158         20       RQ     0.93  zs 0.13   3/2-    T=5/2             1997 IT ?\n', isomers=[], isobaric_analog_states=[])]),
#  '11B': Isotope(mass_number_AAA=11, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='11B', element='B', s='', mass_excess=8667.708, mass_excess_systematics=False, mass_excess_uncertainty=0.012, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='011 0050   11B      8667.708      0.012                               stbl              3/2-*         12          1920 IS=80.35 44\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=11, atomic_number_ZZZ=5, atomic_number_i=8, nucleide='11B', element='B', s='i', mass_excess=21228.0, mass_excess_systematics=False, mass_excess_uncertainty=9.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='011 0058   11B  i  21228          9       12560          9       RQ              T=3/2  1/2+,(3/2+)   12          1963 \n', isomers=[], isobaric_analog_states=[]), Isotope(mass_number_AAA=11, atomic_number_ZZZ=5, atomic_number_i=9, nucleide='11B', element='B', s='j', mass_excess=42230.0, mass_excess_systematics=False, mass_excess_uncertainty=80.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='011 0059   11B  j  42230         80       33570         80       2p                     3/2-    T=5/2                  \n', isomers=[], isobaric_analog_states=[])]),
#  '11C': Isotope(mass_number_AAA=11, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='11C', element='C', s='', mass_excess=10649.4, mass_excess_systematics=False, mass_excess_uncertainty=0.06, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1220.412, half_life_str='20.3402 m', nubase2020_line='011 0060   11C     10649.40       0.06                                 20.3402 m 0.0053 3/2-*         12          1934 B+=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=11, atomic_number_ZZZ=6, atomic_number_i=8, nucleide='11C', element='C', s='i', mass_excess=22810.0, mass_excess_systematics=False, mass_excess_uncertainty=40.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='011 0068   11C  i  22810         40       12160         40       RQ                     1/2+    T=3/2 12          1971 p=?\n', isomers=[], isobaric_analog_states=[])]),
#  '11N': Isotope(mass_number_AAA=11, atomic_number_ZZZ=7, atomic_number_i=0, nucleide='11N', element='N', s='', mass_excess=24366.0, mass_excess_systematics=False, mass_excess_uncertainty=5.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5.85e-22, half_life_str='585 ys', nubase2020_line='011 0070   11N     24366          5                                   585     ys 7      1/2+          12          1974 p=100\n', isomers=[Isotope(mass_number_AAA=11, atomic_number_ZZZ=7, atomic_number_i=1, nucleide='11N', element='N', s='m', mass_excess=25110.0, mass_excess_systematics=False, mass_excess_uncertainty=60.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=6.899999999999999e-22, half_life_str='690 ys', nubase2020_line='011 0071   11N  m  25110         60         740         60            690     ys 80     1/2-          12          1974 p=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '11O': Isotope(mass_number_AAA=11, atomic_number_ZZZ=8, atomic_number_i=0, nucleide='11O', element='O', s='', mass_excess=47740.0, mass_excess_systematics=False, mass_excess_uncertainty=60.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.9799999999999998e-22, half_life_str='198 ys', nubase2020_line='011 0080   11O     47740         60                                   198     ys 12     (3/2-)        20          2019 2p=100\n', isomers=[], isobaric_analog_states=[]),
#  '12Li': Isotope(mass_number_AAA=12, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='12Li', element='Li', s='', mass_excess=49010.0, mass_excess_systematics=False, mass_excess_uncertainty=30.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='012 0030   12Li    49010         30                                                     (1-,2-)       17          2008 n ?\n', isomers=[], isobaric_analog_states=[]),
#  '12Be': Isotope(mass_number_AAA=12, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='12Be', element='Be', s='', mass_excess=25077.8, mass_excess_systematics=False, mass_excess_uncertainty=1.9, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.02146, half_life_str='21.46 ms', nubase2020_line='012 0040   12Be    25077.8        1.9                                  21.46  ms 0.05   0+            17          1966 B-=100;B-n=0.50 3\n', isomers=[Isotope(mass_number_AAA=12, atomic_number_ZZZ=4, atomic_number_i=1, nucleide='12Be', element='Be', s='m', mass_excess=27328.8, mass_excess_systematics=False, mass_excess_uncertainty=2.1, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2.33e-07, half_life_str='233 ns', nubase2020_line='012 0041   12Be m  27328.8        2.1      2251          1            233     ns 7      0+            17          2007 IT=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '12B': Isotope(mass_number_AAA=12, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='12B', element='B', s='', mass_excess=13369.4, mass_excess_systematics=False, mass_excess_uncertainty=1.3, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.0202, half_life_str='20.20 ms', nubase2020_line='012 0050   12B     13369.4        1.3                                  20.20  ms 0.02   1+*           17          1935 B-=100;B-A=0.60 2\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=12, atomic_number_ZZZ=5, atomic_number_i=8, nucleide='12B', element='B', s='i', mass_excess=26088.0, mass_excess_systematics=False, mass_excess_uncertainty=19.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='012 0058   12B  i  26088         19       12719         19       RQ                     0+      T=2   17               \n', isomers=[], isobaric_analog_states=[])]),
#  '12C': Isotope(mass_number_AAA=12, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='12C', element='C', s='', mass_excess=0.0, mass_excess_systematics=False, mass_excess_uncertainty=0.0, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='012 0060   12C         0.0        0.0                                 stbl              0+            17          1919 IS=98.94 6\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=12, atomic_number_ZZZ=6, atomic_number_i=8, nucleide='12C', element='C', s='i', mass_excess=15108.0, mass_excess_systematics=False, mass_excess_uncertainty=3.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='012 0068   12C  i  15108          3       15108          3       RQ                     1+      T=1   17               IT=?;A ?\n', isomers=[], isobaric_analog_states=[]), Isotope(mass_number_AAA=12, atomic_number_ZZZ=6, atomic_number_i=9, nucleide='12C', element='C', s='j', mass_excess=27595.0, mass_excess_systematics=False, mass_excess_uncertainty=2.4, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='012 0069   12C  j  27595.0        2.4     27595.0        2.4     RQ                     0+      T=2   17               \n', isomers=[], isobaric_analog_states=[])]),
#  '12N': Isotope(mass_number_AAA=12, atomic_number_ZZZ=7, atomic_number_i=0, nucleide='12N', element='N', s='', mass_excess=17338.1, mass_excess_systematics=False, mass_excess_uncertainty=1.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.011, half_life_str='11.000 ms', nubase2020_line='012 0070   12N     17338.1        1.0                                  11.000 ms 0.016  1+*           17          1949 B+=100;B+A=1.93 4\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=12, atomic_number_ZZZ=7, atomic_number_i=8, nucleide='12N', element='N', s='i', mass_excess=29580.0, mass_excess_systematics=False, mass_excess_uncertainty=4.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5e-21, half_life_str='>5 zs', nubase2020_line='012 0078   12N  i  29580          4       12242          4       2p    >5     zs        (0+)    T=2   17               \n', isomers=[], isobaric_analog_states=[])]),
#  '12O': Isotope(mass_number_AAA=12, atomic_number_ZZZ=8, atomic_number_i=0, nucleide='12O', element='O', s='', mass_excess=32013.0, mass_excess_systematics=False, mass_excess_uncertainty=12.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=8.899999999999999e-21, half_life_str='8.9 zs', nubase2020_line='012 0080   12O     32013         12                                     8.9   zs 3.3    0+            17          1978 2p=100\n', isomers=[], isobaric_analog_states=[]),
#  '13Li': Isotope(mass_number_AAA=13, atomic_number_ZZZ=3, atomic_number_i=0, nucleide='13Li', element='Li', s='', mass_excess=56980.0, mass_excess_systematics=False, mass_excess_uncertainty=70.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=3.2999999999999993e-21, half_life_str='3.3 zs', nubase2020_line='013 0030   13Li    56980         70                                     3.3   zs 1.2    3/2-#                     2008 2n=100\n', isomers=[], isobaric_analog_states=[]),
#  '13Be': Isotope(mass_number_AAA=13, atomic_number_ZZZ=4, atomic_number_i=3, nucleide='13Be', element='Be', s='p', mass_excess=35160.0, mass_excess_systematics=False, mass_excess_uncertainty=50.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='013 0043   13Be p  35160         50        1500         50       RQ                     (5/2+)                    1992 \n', isomers=[], isobaric_analog_states=[]),
#  '13B': Isotope(mass_number_AAA=13, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='13B', element='B', s='', mass_excess=16561.9, mass_excess_systematics=False, mass_excess_uncertainty=1.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.01716, half_life_str='17.16 ms', nubase2020_line='013 0050   13B     16561.9        1.0                                  17.16  ms 0.18   3/2-          00          1956 B-=100;B-n=0.266 36\n', isomers=[], isobaric_analog_states=[]),
#  '13C': Isotope(mass_number_AAA=13, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='13C', element='C', s='', mass_excess=3125.0093, mass_excess_systematics=False, mass_excess_uncertainty=0.0002, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='013 0060   13C      3125.0093     0.0002                              stbl              1/2-*         01          1929 IS=1.06 6\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=13, atomic_number_ZZZ=6, atomic_number_i=8, nucleide='13C', element='C', s='i', mass_excess=18233.8, mass_excess_systematics=False, mass_excess_uncertainty=1.1, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='013 0068   13C  i  18233.8        1.1     15108.8        1.1     RQ                     3/2-    T=3/2 00               IT=0.82 7;n ?;A ?\n', isomers=[], isobaric_analog_states=[])]),
#  '13N': Isotope(mass_number_AAA=13, atomic_number_ZZZ=7, atomic_number_i=0, nucleide='13N', element='N', s='', mass_excess=5345.48, mass_excess_systematics=False, mass_excess_uncertainty=0.27, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=597.9, half_life_str='9.965 m', nubase2020_line='013 0070   13N      5345.48       0.27                                  9.965  m 0.004  1/2-*         00          1934 B+=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=13, atomic_number_ZZZ=7, atomic_number_i=8, nucleide='13N', element='N', s='i', mass_excess=20410.59, mass_excess_systematics=False, mass_excess_uncertainty=0.18, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='013 0078   13N  i  20410.59       0.18    15065.1        0.3     RQ                     3/2-    T=3/2 00               IT=4.9 3;p ?;A ?\n', isomers=[], isobaric_analog_states=[])]),
#  '13O': Isotope(mass_number_AAA=13, atomic_number_ZZZ=8, atomic_number_i=0, nucleide='13O', element='O', s='', mass_excess=23115.0, mass_excess_systematics=False, mass_excess_uncertainty=10.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.00858, half_life_str='8.58 ms', nubase2020_line='013 0080   13O     23115         10                                     8.58  ms 0.05   (3/2-)        00          1963 B+=100;B+p=10.9 2\n', isomers=[], isobaric_analog_states=[]),
#  '13F': Isotope(mass_number_AAA=13, atomic_number_ZZZ=9, atomic_number_i=0, nucleide='13F', element='F', s='', mass_excess=42030.0, mass_excess_systematics=True, mass_excess_uncertainty=500.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='013 0090   13F     42030#       500#                                                    1/2+#                          p ?\n', isomers=[], isobaric_analog_states=[]),
#  '14Be': Isotope(mass_number_AAA=14, atomic_number_ZZZ=4, atomic_number_i=3, nucleide='14Be', element='Be', s='p', mass_excess=41470.0, mass_excess_systematics=False, mass_excess_uncertainty=60.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='014 0043   14Be p  41470         60        1520        150       RQ                     (2+)                      1995 \n', isomers=[], isobaric_analog_states=[]),
#  '14B': Isotope(mass_number_AAA=14, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='14B', element='B', s='', mass_excess=23664.0, mass_excess_systematics=False, mass_excess_uncertainty=21.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.01236, half_life_str='12.36 ms', nubase2020_line='014 0050   14B     23664         21                                    12.36  ms 0.29   2-            01          1966 B-=100;B-n=6.04 23;B-2n ?\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=14, atomic_number_ZZZ=5, atomic_number_i=8, nucleide='14B', element='B', s='i', mass_excess=40728.0, mass_excess_systematics=False, mass_excess_uncertainty=20.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=4.15e-21, half_life_str='4.15 zs', nubase2020_line='014 0058   14B  i  40728         20       17065         29       RQ     4.15  zs 1.9    0+      T=3               2001 IT ?\n', isomers=[], isobaric_analog_states=[])]),
#  '14C': Isotope(mass_number_AAA=14, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='14C', element='C', s='', mass_excess=3019.893, mass_excess_systematics=False, mass_excess_uncertainty=0.004, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=179878320000.0, half_life_str='5.70 ky', nubase2020_line='014 0060   14C      3019.893      0.004                                 5.70  ky 0.03   0+            01          1936 B-=100\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=14, atomic_number_ZZZ=6, atomic_number_i=8, nucleide='14C', element='C', s='i', mass_excess=25120.0, mass_excess_systematics=False, mass_excess_uncertainty=100.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='014 0068   14C  i  25120        100       22100        100                              (2-)    T=2   01          1989 IT=100\n', isomers=[], isobaric_analog_states=[])]),
#  '14N': Isotope(mass_number_AAA=14, atomic_number_ZZZ=7, atomic_number_i=0, nucleide='14N', element='N', s='', mass_excess=2863.4168, mass_excess_systematics=False, mass_excess_uncertainty=0.0002, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='014 0070   14N      2863.4168     0.0002                              stbl              1+*           01          1920 IS=99.6205 247\n', isomers=[], isobaric_analog_states=[Isotope(mass_number_AAA=14, atomic_number_ZZZ=7, atomic_number_i=8, nucleide='14N', element='N', s='i', mass_excess=5176.007, mass_excess_systematics=False, mass_excess_uncertainty=0.01, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=None, half_life_str='', nubase2020_line='014 0078   14N  i   5176.007      0.010    2312.590      0.010                          0+      T=1   01          1963 IT=100\n', isomers=[], isobaric_analog_states=[])]),
#  '14O': Isotope(mass_number_AAA=14, atomic_number_ZZZ=8, atomic_number_i=0, nucleide='14O', element='O', s='', mass_excess=8007.781, mass_excess_systematics=False, mass_excess_uncertainty=0.025, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=70.621, half_life_str='70.621 s', nubase2020_line='014 0080   14O      8007.781      0.025                                70.621  s 0.011  0+            01          1949 B+=100\n', isomers=[], isobaric_analog_states=[]),
#  '14F': Isotope(mass_number_AAA=14, atomic_number_ZZZ=9, atomic_number_i=0, nucleide='14F', element='F', s='', mass_excess=31960.0, mass_excess_systematics=False, mass_excess_uncertainty=40.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5e-22, half_life_str='500 ys', nubase2020_line='014 0090   14F     31960         40                                   500     ys 60     2-            14          2010 p ?\n', isomers=[], isobaric_analog_states=[]),
#  '15Be': Isotope(mass_number_AAA=15, atomic_number_ZZZ=4, atomic_number_i=0, nucleide='15Be', element='Be', s='', mass_excess=49830.0, mass_excess_systematics=False, mass_excess_uncertainty=170.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=7.9e-22, half_life_str='790 ys', nubase2020_line='015 0040   15Be    49830        170                                   790     ys 270    (5/2+)        15          2013 n=100\n', isomers=[], isobaric_analog_states=[]),
#  '15B': Isotope(mass_number_AAA=15, atomic_number_ZZZ=5, atomic_number_i=0, nucleide='15B', element='B', s='', mass_excess=28957.0, mass_excess_systematics=False, mass_excess_uncertainty=21.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.01018, half_life_str='10.18 ms', nubase2020_line='015 0050   15B     28957         21                                    10.18  ms 0.35   3/2-          02          1966 B-=100;B-n=98.7 10;B-2n<1.5\n', isomers=[], isobaric_analog_states=[]),
#  '15C': Isotope(mass_number_AAA=15, atomic_number_ZZZ=6, atomic_number_i=0, nucleide='15C', element='C', s='', mass_excess=9873.1, mass_excess_systematics=False, mass_excess_uncertainty=0.8, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2.449, half_life_str='2.449 s', nubase2020_line='015 0060   15C      9873.1        0.8                                   2.449  s 0.005  1/2+          02          1950 B-=100\n', isomers=[], isobaric_analog_states=[]),
# ...
#  '90Sr': Isotope(mass_number_AAA=90, atomic_number_ZZZ=38, atomic_number_i=0, nucleide='90Sr', element='Sr', s='', mass_excess=-85950.9, mass_excess_systematics=False, mass_excess_uncertainty=1.4, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=912330216.0, half_life_str='28.91 y', nubase2020_line='090 0380   90Sr   -85950.9        1.4                                  28.91   y 0.03   0+            20          1948 B-=100\n', isomers=[], isobaric_analog_states=[]),
#  '90Y': Isotope(mass_number_AAA=90, atomic_number_ZZZ=39, atomic_number_i=0, nucleide='90Y', element='Y', s='', mass_excess=-86496.9, mass_excess_systematics=False, mass_excess_uncertainty=0.4, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=230580.0, half_life_str='64.05 h', nubase2020_line='090 0390   90Y    -86496.9        0.4                                  64.05   h 0.05   2-*           20          1937 B-=100\n', isomers=[Isotope(mass_number_AAA=90, atomic_number_ZZZ=39, atomic_number_i=1, nucleide='90Y', element='Y', s='m', mass_excess=-85814.9, mass_excess_systematics=False, mass_excess_uncertainty=0.4, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=11613.6, half_life_str='3.226 h', nubase2020_line='090 0391   90Y  m -85814.9        0.4       682.01       0.05           3.226  h 0.011  7+*           20          1961 IT=99.9982 2;B-=0.0018 2\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '90Zr': Isotope(mass_number_AAA=90, atomic_number_ZZZ=40, atomic_number_i=0, nucleide='90Zr', element='Zr', s='', mass_excess=-88772.55, mass_excess_systematics=False, mass_excess_uncertainty=0.12, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='090 0400   90Zr   -88772.55       0.12                                stbl              0+            20          1924 IS=51.45 4\n', isomers=[Isotope(mass_number_AAA=90, atomic_number_ZZZ=40, atomic_number_i=1, nucleide='90Zr', element='Zr', s='m', mass_excess=-86453.55, mass_excess_systematics=False, mass_excess_uncertainty=0.12, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.8092, half_life_str='809.2 ms', nubase2020_line='090 0401   90Zr m -86453.55       0.12     2319.000      0.009        809.2   ms 2.0    5-            20          1972 IT=100\n', isomers=[], isobaric_analog_states=[]), Isotope(mass_number_AAA=90, atomic_number_ZZZ=40, atomic_number_i=2, nucleide='90Zr', element='Zr', s='n', mass_excess=-85183.13, mass_excess_systematics=False, mass_excess_uncertainty=0.12, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.31e-07, half_life_str='131 ns', nubase2020_line='090 0402   90Zr n -85183.13       0.12     3589.418      0.015        131     ns 4      8+            20          1977 IT=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '90Nb': Isotope(mass_number_AAA=90, atomic_number_ZZZ=41, atomic_number_i=5, nucleide='90Nb', element='Nb', s='r', mass_excess=-80782.0, mass_excess_systematics=False, mass_excess_uncertainty=3.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=4.71e-07, half_life_str='471 ns', nubase2020_line='090 0415   90Nb r -80782          3        1880.21       0.20         471     ns 6      (11-)         20          1978 IT=100\n', isomers=[], isobaric_analog_states=[]),
#  '90Mo': Isotope(mass_number_AAA=90, atomic_number_ZZZ=42, atomic_number_i=0, nucleide='90Mo', element='Mo', s='', mass_excess=-80173.0, mass_excess_systematics=False, mass_excess_uncertainty=3.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=20016.0, half_life_str='5.56 h', nubase2020_line='090 0420   90Mo   -80173          3                                     5.56   h 0.09   0+            20          1953 B+=100\n', isomers=[Isotope(mass_number_AAA=90, atomic_number_ZZZ=42, atomic_number_i=1, nucleide='90Mo', element='Mo', s='m', mass_excess=-77298.0, mass_excess_systematics=False, mass_excess_uncertainty=3.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=1.1399999999999999e-06, half_life_str='1.14 us', nubase2020_line='090 0421   90Mo m -77298          3        2874.73       0.15           1.14  us 0.05   8+            20          1971 IT=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '90Tc': Isotope(mass_number_AAA=90, atomic_number_ZZZ=43, atomic_number_i=0, nucleide='90Tc', element='Tc', s='', mass_excess=-70724.7, mass_excess_systematics=False, mass_excess_uncertainty=1.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=49.2, half_life_str='49.2 s', nubase2020_line='090 0430   90Tc   -70724.7        1.0                                  49.2    s 0.4    (8+)          20          1974 B+=100\n', isomers=[Isotope(mass_number_AAA=90, atomic_number_ZZZ=43, atomic_number_i=1, nucleide='90Tc', element='Tc', s='m', mass_excess=-70580.7, mass_excess_systematics=False, mass_excess_uncertainty=1.3, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=8.7, half_life_str='8.7 s', nubase2020_line='090 0431   90Tc m -70580.7        1.3       144.0        1.7     MD     8.7    s 0.2    1+            20          1974 B+=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '90Ru': Isotope(mass_number_AAA=90, atomic_number_ZZZ=44, atomic_number_i=0, nucleide='90Ru', element='Ru', s='', mass_excess=-64884.0, mass_excess_systematics=False, mass_excess_uncertainty=4.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=11.7, half_life_str='11.7 s', nubase2020_line='090 0440   90Ru   -64884          4                                    11.7    s 0.9    0+            20          1991 B+=100\n', isomers=[], isobaric_analog_states=[]),
#  '90Rh': Isotope(mass_number_AAA=90, atomic_number_ZZZ=45, atomic_number_i=0, nucleide='90Rh', element='Rh', s='', mass_excess=-51630.0, mass_excess_systematics=True, mass_excess_uncertainty=200.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=False, half_life=0.029, half_life_str='29 ms', nubase2020_line='090 0450   90Rh   -51630#       200#                               *   29     ms 3      (0+)          20          1994 B+=100;B+p<0.7\n', isomers=[Isotope(mass_number_AAA=90, atomic_number_ZZZ=45, atomic_number_i=1, nucleide='90Rh', element='Rh', s='m', mass_excess=-51630.0, mass_excess_systematics=True, mass_excess_uncertainty=540.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=False, half_life=0.56, half_life_str='0.56 s', nubase2020_line='090 0451   90Rh m -51630#       540#          0#       500#        *    0.56   s 0.02   (7+)          20          2001 B+=100;B+p=9.6 10\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '90Pd': Isotope(mass_number_AAA=90, atomic_number_ZZZ=46, atomic_number_i=0, nucleide='90Pd', element='Pd', s='', mass_excess=-39710.0, mass_excess_systematics=True, mass_excess_uncertainty=400.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=False, half_life=0.01, half_life_str='10# ms', nubase2020_line='090 0460   90Pd   -39710#       400#                                   10#    ms >400ns 0+            20          2016 B+ ?; B+p ? 2p ?\n', isomers=[], isobaric_analog_states=[]),
#  '91As': Isotope(mass_number_AAA=91, atomic_number_ZZZ=33, atomic_number_i=0, nucleide='91As', element='As', s='', mass_excess=-36500.0, mass_excess_systematics=True, mass_excess_uncertainty=400.0, mass_excess_uncertainty_systematics=False, stable=False, p_unstable=False, half_life=0.1, half_life_str='100# ms', nubase2020_line='091 0330   91As   -36500#       400#                                  100#    ms >300ns 5/2-#         13          1997 B- ?;B-n ?;B-2n ?\n', isomers=[], isobaric_analog_states=[]),
#  '91Se': Isotope(mass_number_AAA=91, atomic_number_ZZZ=34, atomic_number_i=0, nucleide='91Se', element='Se', s='', mass_excess=-50580.0, mass_excess_systematics=False, mass_excess_uncertainty=430.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.27, half_life_str='270 ms', nubase2020_line='091 0340   91Se   -50580        430                                   270     ms 50     1/2+#         13          1975 B-=100;B-n=21 10;B-2n ?\n', isomers=[], isobaric_analog_states=[]),
#  '91Br': Isotope(mass_number_AAA=91, atomic_number_ZZZ=35, atomic_number_i=0, nucleide='91Br', element='Br', s='', mass_excess=-61107.0, mass_excess_systematics=False, mass_excess_uncertainty=4.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=0.543, half_life_str='543 ms', nubase2020_line='091 0350   91Br   -61107          4                                   543     ms 4      5/2-#         13          1974 B-=100;B-n=29.5 5\n', isomers=[], isobaric_analog_states=[]),
#  '91Kr': Isotope(mass_number_AAA=91, atomic_number_ZZZ=36, atomic_number_i=0, nucleide='91Kr', element='Kr', s='', mass_excess=-70974.0, mass_excess_systematics=False, mass_excess_uncertainty=2.2, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=8.57, half_life_str='8.57 s', nubase2020_line='091 0360   91Kr   -70974.0        2.2                                   8.57   s 0.04   5/2+*         13          1951 B-=100;B-n ?\n', isomers=[], isobaric_analog_states=[]),
#  '91Rb': Isotope(mass_number_AAA=91, atomic_number_ZZZ=37, atomic_number_i=0, nucleide='91Rb', element='Rb', s='', mass_excess=-77745.0, mass_excess_systematics=False, mass_excess_uncertainty=8.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=58.2, half_life_str='58.2 s', nubase2020_line='091 0370   91Rb   -77745          8                                    58.2    s 0.3    3/2-*         13          1951 B-=100;B-n ?\n', isomers=[], isobaric_analog_states=[]),
#  '91Sr': Isotope(mass_number_AAA=91, atomic_number_ZZZ=38, atomic_number_i=0, nucleide='91Sr', element='Sr', s='', mass_excess=-83652.0, mass_excess_systematics=False, mass_excess_uncertainty=5.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=34740.0, half_life_str='9.65 h', nubase2020_line='091 0380   91Sr   -83652          5                                     9.65   h 0.06   5/2+*         13          1943 B-=100\n', isomers=[], isobaric_analog_states=[]),
#  '91Y': Isotope(mass_number_AAA=91, atomic_number_ZZZ=39, atomic_number_i=0, nucleide='91Y', element='Y', s='', mass_excess=-86351.3, mass_excess_systematics=False, mass_excess_uncertainty=1.8, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5055264.0, half_life_str='58.51 d', nubase2020_line='091 0390   91Y    -86351.3        1.8                                  58.51   d 0.06   1/2-*         13          1943 B-=100\n', isomers=[Isotope(mass_number_AAA=91, atomic_number_ZZZ=39, atomic_number_i=1, nucleide='91Y', element='Y', s='m', mass_excess=-85795.7, mass_excess_systematics=False, mass_excess_uncertainty=1.8, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=2982.6, half_life_str='49.71 m', nubase2020_line='091 0391   91Y  m -85795.7        1.8       555.58       0.05          49.71   m 0.04   9/2+          13          1953 IT~100;B- ?\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '91Zr': Isotope(mass_number_AAA=91, atomic_number_ZZZ=40, atomic_number_i=0, nucleide='91Zr', element='Zr', s='', mass_excess=-87895.59, mass_excess_systematics=False, mass_excess_uncertainty=0.09, mass_excess_uncertainty_systematics=True, stable=True, p_unstable=False, half_life=None, half_life_str='stbl', nubase2020_line='091 0400   91Zr   -87895.59       0.09                                stbl              5/2+*         13          1934 IS=11.22 5\n', isomers=[Isotope(mass_number_AAA=91, atomic_number_ZZZ=40, atomic_number_i=1, nucleide='91Zr', element='Zr', s='m', mass_excess=-84728.3, mass_excess_systematics=False, mass_excess_uncertainty=0.4, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=4.35e-06, half_life_str='4.35 us', nubase2020_line='091 0401   91Zr m -84728.3        0.4      3167.3        0.4            4.35  us 0.14   (21/2+)       13          1985 IT=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '91Nb': Isotope(mass_number_AAA=91, atomic_number_ZZZ=41, atomic_number_i=0, nucleide='91Nb', element='Nb', s='', mass_excess=-86638.0, mass_excess_systematics=False, mass_excess_uncertainty=2.9, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=21459168000.0, half_life_str='680 y', nubase2020_line='091 0410   91Nb   -86638.0        2.9                                 680      y 130    9/2+*         13          1951 EC~100;e+=0.0138 25\n', isomers=[Isotope(mass_number_AAA=91, atomic_number_ZZZ=41, atomic_number_i=1, nucleide='91Nb', element='Nb', s='m', mass_excess=-86533.4, mass_excess_systematics=False, mass_excess_uncertainty=2.9, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=5258304.0, half_life_str='60.86 d', nubase2020_line='091 0411   91Nb m -86533.4        2.9       104.60       0.05          60.86   d 0.22   1/2-*         13          1950 IT=96.6 5;EC=3.4 5;e+=0.0028 2\n', isomers=[], isobaric_analog_states=[]), Isotope(mass_number_AAA=91, atomic_number_ZZZ=41, atomic_number_i=2, nucleide='91Nb', element='Nb', s='n', mass_excess=-84603.6, mass_excess_systematics=False, mass_excess_uncertainty=2.9, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=3.7599999999999996e-06, half_life_str='3.76 us', nubase2020_line='091 0412   91Nb n -84603.6        2.9      2034.42       0.20           3.76  us 0.12   (17/2-)       13          1974 IT=100\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  '91Mo': Isotope(mass_number_AAA=91, atomic_number_ZZZ=42, atomic_number_i=0, nucleide='91Mo', element='Mo', s='', mass_excess=-82209.0, mass_excess_systematics=False, mass_excess_uncertainty=6.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=929.4, half_life_str='15.49 m', nubase2020_line='091 0420   91Mo   -82209          6                                    15.49   m 0.01   9/2+          13          1948 B+=100\n', isomers=[Isotope(mass_number_AAA=91, atomic_number_ZZZ=42, atomic_number_i=1, nucleide='91Mo', element='Mo', s='m', mass_excess=-81556.0, mass_excess_systematics=False, mass_excess_uncertainty=6.0, mass_excess_uncertainty_systematics=True, stable=False, p_unstable=False, half_life=64.6, half_life_str='64.6 s', nubase2020_line='091 0421   91Mo m -81556          6         653.01       0.09          64.6    s 0.6    1/2-          13          1953 IT=50.0 16;B+=50.0 16\n', isomers=[], isobaric_analog_states=[])], isobaric_analog_states=[]),
#  ...}
